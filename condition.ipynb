# %%
a = input("Введите имя")
print("Привет,", a)
# Out:
# Привет, Вика

# %%
a = int(input("Введите первое число"))
b = int(input("Введите второе число"))
sum = a + b
print(sum)
# Out:
# 8

# %%
a = int(input("Введите первое число"))
kvadrat = a * a
print(kvadrat)
# Out:
# 16

# %%
minute = int(input("Введите минуты"))
print("часы:", minute // 60, "минуты:", minute % 60)
# Out:
# часы: 2 минуты: 30

# %%
a = int(input("Введите высоту"))
b = int(input("Введите ширину"))
ploshchad = a * b
print("Площадь равна:", ploshchad)
# Out:
# Площадь равна: 50

# %%
a = int(input("Введите температуру в градусах Цельсия"))
Fahrenheit = (a * 1.8) + 32
print(Fahrenheit)
# Out:
# 77.0

# %%
a = int(input("Введите количество яблок"))
b = int(input("Введите количество людей"))
kazhdomu = a // b
ostalos = a % b
print("каждому по:", kazhdomu)
print("осталось:",  ostalos)
# Out:
# каждому по: 0
# осталось: 3

# %%
a = int(input("Введите число для проверки на четность"))
if a % 2 == 0:
    print("true")
else:
    print("false")
# Out:
# false

# %%
a = int(input("Введите расстояние"))
b = int(input("Введите время"))
doroga = a // b
print(doroga, "км/ч")
# Out:
# 50 км/ч

# %%
a = int(input("Введите число"))
b = int(input("Введите %"))
protsent = (a * b) // 100
print(protsent)
# Out:
# 200

# %%
a = int(input("Введите первое число"))
b = int(input("Введите второе число"))
c = int(input("Введите третье число"))
srednee = (a + b + c) / 3
print(srednee)
# Out:
# 3.0

# %%
# 11)Среднее значение трех чисел
# Запросите у пользователя три числа и выведите их среднее арифметическое.
# Пример:
# Ввод:
# Введите первое число: 4
# Введите второе число: 8
# Введите третье число: 6
# Вывод:
# Среднее значение: 6.0


# 12)Перевод секунд в часы, минуты и секунды
# Запросите у пользователя количество секунд и преобразуйте это значение в часы, минуты и секунды.
# Пример:
# Ввод:
# Введите количество секунд: 3671
# Вывод:
# 1 час(а), 1 минута, 11 секунд


# 13)Конвертер валют с фиксированным курсом
# Напишите программу, которая конвертирует доллары в евро. Пусть курс доллара к евро будет фиксированным, например, 1 USD = 0.85 EUR.
# Пример:
# Ввод:
# Введите количество долларов: 100
# Вывод:
# Это 85.0 евро.


# 14)Год рождения
# Запросите у пользователя его текущий возраст и выведите год, в котором он родился.
# Пример:
# Ввод:
# Введите ваш возраст: 16
# Вывод:
# Вы родились в 2008 году.


# 15)Число десятилетий
# Запросите у пользователя его возраст и посчитайте, сколько десятилетий он прожил.
# Пример:
# Ввод:
# Введите ваш возраст: 25
# Вывод:
# Вы прожили 2 полных десятилетия.
